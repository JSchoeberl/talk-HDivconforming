# %% [markdown]
# # Turbulence
#
# work with Xaver Mooslechner

# %% [markdown]
# ![Xaver1.png](attachment:Xaver1.png)

# %% [markdown]
# ![Xaver2.png](attachment:Xaver2.png)

# %% [markdown]
# ![Xaver3.png](attachment:Xaver3.png)

# %% [markdown]
# ![Xaver4.png](attachment:Xaver4.png)
